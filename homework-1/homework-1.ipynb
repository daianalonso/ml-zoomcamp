# %%
import pandas as pd
import wget
import numpy as np

# %% [markdown]
# See pandas version

# %%
pd.__version__
# Out:
# '3.0.6'

# %% [markdown]
# Downloading dataset

# %%
filename = wget.download("https://raw.githubusercontent.com/DataTalksClub/machine-learning-zoomcamp/main/cohorts/2026/data/car_fuel_efficiency_2026.csv")
df_cars = pd.read_csv(filename)

# %% [markdown]
# How many records are in the dataset?

# %%
df_cars.shape[0]
# Out:
# 10000

# %%
df_cars.columns
# Out:
# Index(['model_year', 'origin', 'fuel_type', 'drivetrain', 'num_doors',
#        'engine_displacement', 'num_cylinders', 'horsepower', 'vehicle_weight',
#        'acceleration', 'fuel_efficiency_mpg'],
#       dtype='str')

# %% [markdown]
# How many fuel types are presented in the dataset?

# %%
df_cars.fuel_type.nunique()
# Out:
# 3

# %% [markdown]
# How many columns in the dataset have missing values?

# %%
df_cars.isnull().any()
# Out:
# model_year             False
# origin                 False
# fuel_type              False
# drivetrain             False
# num_doors              False
# engine_displacement    False
# num_cylinders          False
# horsepower              True
# vehicle_weight         False
# acceleration            True
# fuel_efficiency_mpg    False
# dtype: bool

# %% [markdown]
# What's the maximum fuel efficiency of cars from Asia?

# %%
df_cars[df_cars["origin"] == "Asia"].fuel_efficiency_mpg.max()
# Out:
# np.float64(41.2)

# %% [markdown]
# 1. Find the median value of the horsepower column in the dataset.
# 2. Next, calculate the most frequent value of the same horsepower column.
# 3. Use the fillna method to fill the missing values in the horsepower column with the most frequent value from the previous step.
# 4. Now, calculate the median value of horsepower once again.
# - Has it changed?

# %%
median_before = df_cars["horsepower"].median()
most_freq_horsepower = df_cars["horsepower"].mode()[0]
df_cars.fillna({'horsepower': most_freq_horsepower}, inplace=True)
median_now = df_cars["horsepower"].median()
print(f'Median before: {median_before}, Median after: {median_now}')
# Out:
# Median before: 254.0, Median after: 252.0

# %% [markdown]
# 1. Select all the cars from Asia
# 2. Select only columns vehicle_weight and model_year
# 3. Select the first 7 values
# 4. Get the underlying NumPy array. Let's call it X.
# 5. Compute matrix-matrix multiplication between the transpose of X and X. To get the transpose, use X.T. Let's call the result XTX.
# 6. Invert XTX.
# 7. Create an array y with values [1100, 1300, 800, 900, 1000, 1100, 1200].
# 8. Multiply the inverse of XTX with the transpose of X, and then multiply the result by y. Call the result w.
# 9. What's the sum of all the elements of the result?

# %%
X = df_cars[df_cars["origin"] == "Asia"][["vehicle_weight", "model_year"]].head(7).values
XTX = X.T.dot(X)
XTX_inv = np.linalg.inv(XTX)
y = np.array([1100, 1300, 800, 900, 1000, 1100, 1200])
w = XTX_inv.T.dot(X.T).dot(y)
w.sum()
# Out:
# np.float64(0.36919696904925486)
